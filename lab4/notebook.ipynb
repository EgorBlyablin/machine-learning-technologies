# %% [markdown]
# # **Лабораторная работа 4**: Линейные модели, SVM и деревья решений.

# %% [markdown]
# ## Загрузка данных

# %%
import polars as pl


df = pl.read_csv("WineQT.csv")
df
# Out:
# shape: (1_143, 13)
# ┌─────────┬──────────┬─────────────┬────────────────┬───┬───────────┬─────────┬─────────┬──────┐
# │ fixed   ┆ volatile ┆ citric acid ┆ residual sugar ┆ … ┆ sulphates ┆ alcohol ┆ quality ┆ Id   │
# │ acidity ┆ acidity  ┆ ---         ┆ ---            ┆   ┆ ---       ┆ ---     ┆ ---     ┆ ---  │
# │ ---     ┆ ---      ┆ f64         ┆ f64            ┆   ┆ f64       ┆ f64     ┆ i64     ┆ i64  │
# │ f64     ┆ f64      ┆             ┆                ┆   ┆           ┆         ┆         ┆      │
# ╞═════════╪══════════╪═════════════╪════════════════╪═══╪═══════════╪═════════╪═════════╪══════╡
# │ 7.4     ┆ 0.7      ┆ 0.0         ┆ 1.9            ┆ … ┆ 0.56      ┆ 9.4     ┆ 5       ┆ 0    │
# │ 7.8     ┆ 0.88     ┆ 0.0         ┆ 2.6            ┆ … ┆ 0.68      ┆ 9.8     ┆ 5       ┆ 1    │
# │ 7.8     ┆ 0.76     ┆ 0.04        ┆ 2.3            ┆ … ┆ 0.65      ┆ 9.8     ┆ 5       ┆ 2    │
# ...

# %% [markdown]
# ## Подготовка данных

# %%
X = df.drop("quality")
y = df.get_column("quality")

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=1234, stratify=y
)

# %% [markdown]
# ## Обучение моделей
#
# ### Линейная модель

# %%
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression


linreg = Pipeline(
    steps=[
        ("model", LinearRegression()),
    ]
)

linreg.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('model', LinearRegression())])

# %% [markdown]
# ### SVM

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVR

numeric_preprocess = Pipeline(
    steps=[
        ("scaler", StandardScaler()),
    ]
)

svm_reg = Pipeline(
    steps=[
        ("preprocess", numeric_preprocess),
        ("model", SVR()),
    ]
)

svm_reg.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocess', Pipeline(steps=[('scaler', StandardScaler())])),
#                 ('model', SVR())])

# %% [markdown]
# ### Дерево решений

# %%
from sklearn.tree import DecisionTreeRegressor

tree_reg = Pipeline(
    steps=[
        ("preprocess", numeric_preprocess),
        ("model", DecisionTreeRegressor(max_depth=3, random_state=1234)),
    ]
)

tree_reg.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocess', Pipeline(steps=[('scaler', StandardScaler())])),
#                 ('model',
#                  DecisionTreeRegressor(max_depth=3, random_state=1234))])

# %% [markdown]
# ## Оценка качества моделей

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np


def eval_reg(name, model, X_train, y_train, X_test, y_test):
    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)

    metrics = {
        "model": name,
        "train_rmse": np.sqrt(mean_squared_error(y_train, y_train_pred)),
        "test_rmse": np.sqrt(mean_squared_error(y_test, y_test_pred)),
        "train_mae": mean_absolute_error(y_train, y_train_pred),
        "test_mae": mean_absolute_error(y_test, y_test_pred),
        "train_r2": r2_score(y_train, y_train_pred),
        "test_r2": r2_score(y_test, y_test_pred),
    }
    return metrics


results = []
for name, m in [
    ("LinearRegression", linreg),
    ("SVR", svm_reg),
    ("DecisionTree", tree_reg),
]:
    results.append(eval_reg(name, m, X_train, y_train, X_test, y_test))

results_df = pl.DataFrame(results)
print(results_df)
# Out:
# shape: (3, 7)
# ┌──────────────────┬────────────┬───────────┬───────────┬──────────┬──────────┬──────────┐
# │ model            ┆ train_rmse ┆ test_rmse ┆ train_mae ┆ test_mae ┆ train_r2 ┆ test_r2  │
# │ ---              ┆ ---        ┆ ---       ┆ ---       ┆ ---      ┆ ---      ┆ ---      │
# │ str              ┆ f64        ┆ f64       ┆ f64       ┆ f64      ┆ f64      ┆ f64      │
# ╞══════════════════╪════════════╪═══════════╪═══════════╪══════════╪══════════╪══════════╡
# │ LinearRegression ┆ 0.641029   ┆ 0.622725  ┆ 0.500172  ┆ 0.480075 ┆ 0.367512 ┆ 0.398951 │
# │ SVR              ┆ 0.521174   ┆ 0.618594  ┆ 0.360084  ┆ 0.450798 ┆ 0.581917 ┆ 0.406898 │
# │ DecisionTree     ┆ 0.653632   ┆ 0.677283  ┆ 0.509245  ┆ 0.531329 ┆ 0.342398 ┆ 0.28902  │
# └──────────────────┴────────────┴───────────┴───────────┴──────────┴──────────┴──────────┘

# %% [markdown]
# ## Анализ дерева решений
#
# ### График важности признаков

# %%
import matplotlib.pyplot as plt

fitted_tree = tree_reg.named_steps["model"]
feature_names = X.columns
importances = fitted_tree.feature_importances_

idx = np.argsort(importances)[::-1]

plt.bar(range(len(idx)), importances[idx])
plt.xticks(range(len(idx)), [feature_names[i] for i in idx], rotation=45, ha="right")
plt.ylabel("Важность признака")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Визуализация правил дерева решений

# %%
from sklearn.tree import plot_tree

plt.figure(figsize=(20, 8))
plot_tree(
    fitted_tree,
    feature_names=feature_names,
    filled=True,
    rounded=True,
)
plt.show()
